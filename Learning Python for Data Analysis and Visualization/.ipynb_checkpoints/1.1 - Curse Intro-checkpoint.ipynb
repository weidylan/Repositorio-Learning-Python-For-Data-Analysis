# %% [markdown]
# # Introdução ao Curso
#
# Este curso abordará Data Analysis and Visualization utilizando a linguagem Python.
#
# Você sabia que atualmente mundo está produzindo mais dados do que nunca?
#
# Na realidade, 90% dos dados foram criados nos últimos 2 anos.
#
# Até 2020 terá mais de 40 zettabytes. Isso é igual a 400 bilhões de gigabytes.
#
# É por isso que as principais empresas de tecnologia, como: Facebook, Linkedln, Twitter, Google... precisam de pessoas para ajudá-las a analisar e entender esses dados.
#
# # Course Overview
#
# * Numpy
# * Pandas
# * Importing and Exporting Data
# * Visualizing data with Matplotlib and Seabonr
# * Data Portfolio Projects
# * Machine Learning with Scikit-Learn
# * Appendix Materials
# * Statistics
# * SQL with Python
# * Web Scraping with Python
# * Special Offer: Complete Python Bootcamp
#
# # Leaning Numpy
#
# Numpy is the fundamental package for scientific computing.
#
# Learn how to use Numpy to create and manipulate arrays with Python.
#
# Resumindo... Numpy é um pacote de extrema importância e significado para Ciência da Computação.
#
# Com ele podemos aprender a criar e manipular arrays.
#
# # Learning Pandas
#
# Learn how to use pandas with Python to create high-performance data structures.
#
# Learn how to use pandas to create Series, DataFrames, and to quick and effective analysis on your data.
#
# Learn about pandas built in visualization tools!
#
# Iremos aprender como usar Pandas para criar séries, dataframes e assim tirar análise de alta performance sobre nossos dados tudo de forma rápida e efetiva.
#
# # Importing Data
#
# Learn how to use Python and Pandas to work with data in a variety of formats.
#
# Vamos aprender a usar Python e Pandas para trabalhar com dados dos mais diversos formatos.
#
# We'll work with JSON, HTML, text, csv, and even Excel files in Python.
#
# Vamos trabalhar com:
#
# * JSON
# * HTML
# * csv
# * txt
#
# # Data Visualization
#
# Learn how to use matplotlib and the seaborn libraries to create beautiful, modern, and informativa visualizations with Python!
#
# Iremos aprender a usar as bibliotecas matplotlib e seaborn para criar visualizações lindas, modernas e informativas.
#
# # Machine Learning with Scikit-Learn
#
# Lear the latest machine learning techniques using the most populas library for machine learning in Python.
#
# Vamos explorar as últimas técnicas de aprendizado de máquina utilizando a mais famosa biblioteca no Python para isso.
#
# # Statistics
#
# Vamos aprender a usar o Scipy para criar distribuições e resolver problemas estatísticos.
#
# # SQL with Python
#
# Learn how to use SQLAlchemy to fully integrate SQL with Python and run SQL queries from a Python environment!
#
# Learn basic SQL commands with Python and Pandas.
#
# # Web Scraping
#
# Learn how to use Python web requests and the Beatiful-Soup library to scrape the web for data.
